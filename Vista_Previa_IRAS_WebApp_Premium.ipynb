# %% [markdown]
# # Vista previa de IRAS WebApp Premium en Google Colab

# %%
# !pip -q install streamlit openpyxl scikit-learn pandas numpy plotly reportlab

# %% [markdown]
# Sube `app.py`, `requirements.txt`, `assets/iras_logo.svg`, `.streamlit/config.toml` y `02_dataset_analitico_IRAS_Lima_150_V2.xlsx`.

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded.keys())

# %%
# !streamlit run app.py --server.port 8501 & npx localtunnel --port 8501
